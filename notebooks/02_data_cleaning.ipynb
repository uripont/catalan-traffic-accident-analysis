# %% [markdown]
# # 2 Data cleaning

# %% [markdown]
# ## 2.1 Import libraries, load dataset

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder

# %%
data_path = '../data/accidents_catalonia_2010_2023.csv'
df = pd.read_csv(data_path)
print(f"Dataset loaded successfully from {data_path}")
# Out:
# Dataset loaded successfully from ../data/accidents_catalonia_2010_2023.csv

# %%
# save original
df_original = df.copy()

# %% [markdown]
# ## 2.2 Drop not needed columns

# %% [markdown]
# First, we extract month from date

# %%
# copy dataset
df_original = df.copy()

# get only month from date
df['Mes'] = pd.to_datetime(df['dat']).dt.month
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3764\1995985882.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Mes'] = pd.to_datetime(df['dat']).dt.month

# %% [markdown]
# Now, we delete the following columns:
# - dat (we only need year and month)
# - pk (we don't need the exact kilometer)
# - nomMun (with *nomCom* and *nomDem* is sufficient)
# - grupDiaLab (we already have *tipDia*)
# - via (too many unique values, and around 10k *Sense especificar*)
#
# - Post-accident variables: D_INFLUIT_BOIRA, D_INFLUIT_CARACT_ENTORN, D_INFLUIT_CIRCULACIO, D_INFLUIT_ESTAT_CLIMA, D_INFLUIT_INTEN_VENT, D_INFLUIT_LLUMINOSITAT, D_INFLUIT_MESU_ESP, D_INFLUIT_OBJ_CALCADA, D_INFLUIT_SOLCS_RASES, D_INFLUIT_VISIBILITAT.

# %%
cols_to_remove = ['dat', 'pk', 'nomMun', 'F_ALTRES_UNIT_IMPLICADES', 'F_UNIT_DESC_IMPLICADES', 'D_ACC_AMB_FUGA', 'D_GRAVETAT', 'D_INFLUIT_BOIRA', 'D_INFLUIT_CARACT_ENTORN', 'D_INFLUIT_CIRCULACIO', 'D_INFLUIT_ESTAT_CLIMA', 'D_INFLUIT_INTEN_VENT', 'D_INFLUIT_LLUMINOSITAT', 'D_INFLUIT_MESU_ESP', 'D_INFLUIT_OBJ_CALCADA', 'D_INFLUIT_SOLCS_RASES', 'D_INFLUIT_VISIBILITAT', 'grupDiaLab', 'via']
df = df.drop(columns=cols_to_remove)
print(f"Number of columns after removal: {len(df.columns)}")
# Out:
# Number of columns after removal: 40

# %% [markdown]
# ## 2.3 Handle missing values

# %%
missing_values = df.isnull().sum()
print("Missing Values per Column:")
print(missing_values[missing_values > 0] if missing_values.sum() > 0 else "No missing values found!")
print(f"\nTotal missing values: {missing_values.sum()}")
# Out:
# Missing Values per Column:
# C_VELOCITAT_VIA              3062
# D_CARACT_ENTORN                41
# D_CARRIL_ESPECIAL            1741
# D_CIRCULACIO_MESURES_ESP       49
# D_REGULACIO_PRIORITAT       17488
# D_SENTITS_VIA                4301
# D_SUBTIPUS_TRAM             16494
# D_TITULARITAT_VIA           12509
# D_TRACAT_ALTIMETRIC          8898
# dtype: int64
#
# Total missing values: 64583

# %% [markdown]
# ### VELOCITAT_VIA

# %% [markdown]
# Replace incorrect values (999km/h) with NaN

# %%
# Replace 999 with NaN
df['C_VELOCITAT_VIA'] = df['C_VELOCITAT_VIA'].replace(999, np.nan)

# %% [markdown]
# Percentage of rows with at least 1 death in the dataset

# %%
# percentage of rows with deaths in dataset
# rows with at least 1 death
rows_with_deaths = df[df['F_MORTS'] > 0]
print(f"Total records: {len(df)}")
print(f"Records with at least 1 death: {len(rows_with_deaths)}")
print(f"Percentage of records with at least 1 death: {len(rows_with_deaths) / len(df) * 100:.1f}%")
# Out:
# Total records: 24478
# Records with at least 1 death: 3093
# Percentage of records with at least 1 death: 12.6%

# %% [markdown]
# Percentage of rows with at least 1 death in records with invalid speed

# %%
# how many records with NAN contain at least 1 death?
speed_missing = df[df['C_VELOCITAT_VIA'].isna()]
print(f"Records with invalid speed: {len(speed_missing)}")
print(f"Deaths in these records: {speed_missing['F_MORTS'].sum()}")
print(f"Percentage of total deaths: {speed_missing['F_MORTS'].sum() / df['F_MORTS'].sum() * 100:.1f}%")
print(f"Percentage of total records: {len(speed_missing) / len(df) * 100:.1f}%")
# Out:
# Records with invalid speed: 4777
# Deaths in these records: 192
# Percentage of total deaths: 5.7%
# Percentage of total records: 19.5%

# %% [markdown]
# Most of the records with invalid VELOCITAT_VIA values have no deaths. We already have many records with no deaths. Therefore, we decide to delete them.

# %%
# delete records with invalid speed
print(f"Dataset size before removing records with invalid speed: {len(df)}")
df = df[df['C_VELOCITAT_VIA'].notna()]
print(f"Dataset size after removing records with invalid speed: {len(df)}")
# Out:
# Dataset size before removing records with invalid speed: 24478
# Dataset size after removing records with invalid speed: 19701

# %% [markdown]
# ### Categorical variables - transform to "Sense Especificar"

# %%
# Change "Sense especificar" to "Sense Especificar" in D_SENTITS_VIA, D_SUBTIPUS_TRAM, D_TRACAT_ALTIMETRIC
cols_se = ['D_SENTITS_VIA', 'D_SUBTIPUS_TRAM', 'D_TRACAT_ALTIMETRIC']

for col in cols_se:
    df[col] = df[col].replace('Sense especificar', 'Sense Especificar')

# %%
cols_to_fill = ['D_CARACT_ENTORN', 'D_CARRIL_ESPECIAL', 'D_CIRCULACIO_MESURES_ESP',
    'D_REGULACIO_PRIORITAT',
    'D_SENTITS_VIA',
    'D_SUBTIPUS_TRAM',
    'D_TITULARITAT_VIA',
    'D_TRACAT_ALTIMETRIC'
]

for col in cols_to_fill:
    df[col] = df[col].fillna('Sense Especificar')

# %%
missing_values = df.isnull().sum()
print("Missing Values per Column:")
print(missing_values[missing_values > 0] if missing_values.sum() > 0 else "No missing values found!")
print(f"\nTotal missing values: {missing_values.sum()}")
# Out:
# Missing Values per Column:
# No missing values found!
#
# Total missing values: 0

# %% [markdown]
# ## 2.4 Convert hour to float

# %%
df['hor'] = df['hor'].astype(str).str.replace(',', '.').astype(float)

# %% [markdown]
# ## 2.5 Encode categorical variables

# %%
# print unique values of each categorical column
for col in df.select_dtypes(include=['object']).columns:
    print(f"\nUnique values in column '{col}':")
    print(df[col].value_counts())
    print("-"*40)
# Out:
# Unique values in column 'zona':
# zona
# Zona urbana    10216
# Carretera       9485
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'nomCom':
# nomCom
# Barcelonès           3584
# Vallès Occidental    2292
# Baix Llobregat       1432
# Vallès Oriental      1146
# Tarragonès            750
# Maresme               722
# Bages                 688
# Selva                 686
# Alt Empordà           682
# Baix Camp             671
# Gironès               652
# Segrià                649
# Osona                 520
# Garraf                475
# Alt Penedès           418
# Baix Ebre             367
# Anoia                 345
# Baix Empordà          343
# Baix Penedès          336
# Montsià               300
# Noguera               251
# Alt Urgell            238
# Garrotxa              217
# Alt Camp              189
# Berguedà              165
# Cerdanya              157
# Pla d'Urgell          155
# Ribera d'Ebre         129
# Pla de l'Estany       121
# Segarra               115
# Urgell                114
# Pallars Jussà          95
# Pallars Sobirà         92
# Solsonès               89
# Conca de Barberà       88
# Garrigues              88
# Ripollès               82
# Terra Alta             65
# Priorat                47
# Moianès                41
# Alta Ribagorça         38
# Aran                   35
# Val d'Aran             32
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'nomDem':
# nomDem
# Barcelona    11839
# Tarragona     2942
# Girona        2885
# Lleida        2035
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_BOIRA':
# D_BOIRA
# No n'hi ha    18242
# Si             1459
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_CARACT_ENTORN':
# D_CARACT_ENTORN
# A nivell             8607
# Sense Especificar    5798
# Mixt                 2908
# Desmunt              1515
# Terraplé              873
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_CARRIL_ESPECIAL':
# D_CARRIL_ESPECIAL
# No n'hi ha                                      18253
# Carril bus                                        362
# Carril bici                                       235
# Carril acceleració                                170
# Altres                                            163
# Carril central                                    162
# Carril d'alentiment                                98
# Carril lent                                        87
# Sense Especificar                                  51
# Carril avançament                                  42
# Habilitació voral/carril addicional                40
# Carril reversible                                  24
# Carril habilitat en sentit contrari habitual       14
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_CIRCULACIO_MESURES_ESP':
# D_CIRCULACIO_MESURES_ESP
# No n'hi ha                         19182
# Obres                                290
# Accident trànsit anterior             67
# Sense Especificar                     49
# Serveis de neteja o manteniment       45
# Esdeveniment extraordinari            43
# Cons                                  14
# Control policial                      11
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_CLIMATOLOGIA':
# D_CLIMATOLOGIA
# Bon temps            18628
# Pluja dèbil            817
# Pluja forta            235
# Calamarsa               12
# Nevant                   8
# Sense especificar        1
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_FUNC_ESP_VIA':
# D_FUNC_ESP_VIA
# Sense funció especial               19320
# Travessera                            237
# Ronda, cinturo o circumval.lacio       85
# Variant                                57
# Sense especificar                       2
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_INTER_SECCIO':
# D_INTER_SECCIO
# En secció                                 13309
# Dintre intersecció                         5195
# Arribant o eixint intersecció fins 50m     1197
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_LIMIT_VELOCITAT':
# D_LIMIT_VELOCITAT
# Genérica via        13192
# Senyal velocitat     6509
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_LLUMINOSITAT':
# D_LLUMINOSITAT
# De dia, dia clar                               13222
# De nit, il·luminació artificial suficient       2105
# De nit, sense llum artificial                   1601
# De nit, il·luminació artificial insuficient     1015
# Alba o capvespre                                 954
# De dia, dia fosc                                 802
# Sense especificar                                  2
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_REGULACIO_PRIORITAT':
# D_REGULACIO_PRIORITAT
# Sense Especificar                             14337
# Senyal Stop o cedeix pas                       2590
# Semàfor                                        1243
# Sols norma prioritat de pas                     890
# Sols marques viàries (inclou pas vianants)      625
# Persona autoritzada                              13
# Altres                                            3
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_SENTITS_VIA':
# D_SENTITS_VIA
# Doble sentit         12902
# Un sol sentit         4533
# Sense Especificar     2266
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_SUBTIPUS_ACCIDENT':
# D_SUBTIPUS_ACCIDENT
# Atropellament                                              4104
# Envestida (frontal lateral)                                3730
# Resta sortides de via                                      2153
# Col·lisió frontal                                          1965
# Fregament o col·lisió lateral                              1892
# Caiguda en la via                                          1877
# Encalç                                                     1707
# Xoc contra objecte/obstacle sense sortida prèvia de via    1043
# Altres                                                      919
# Sortida de via amb xoc o col·lisió                          241
# Sortida de via amb bolcada                                   45
# Xoc amb animal a la calçada                                  15
# Sortida de via amb atropellament                             10
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_SUBTIPUS_TRAM':
# D_SUBTIPUS_TRAM
# Sense Especificar                     13351
# Encreuament o intersecció en X o +     2885
# Intersecció en T o Y                   1927
# Giratòria                              1002
# Enllaç d'entrada o eixida               534
# Pas a nivell                              2
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_SUBZONA':
# D_SUBZONA
# Carretera      9485
# Zona urbana    9292
# Travessera      924
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_SUPERFICIE':
# D_SUPERFICIE
# Sec i net            18784
# Mullat                 640
# Inundat                131
# Relliscós              111
# Gelat                   25
# Nevat                    9
# Sense especificar        1
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_TIPUS_VIA':
# D_TIPUS_VIA
# Via urbana( inclou carrer i carrer residencial)    9386
# Carretera convencional                             8900
# Altres                                              595
# Autovia                                             459
# Autopista                                           199
# Camí rural/pista forestal                           162
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_TITULARITAT_VIA':
# D_TITULARITAT_VIA
# Sense Especificar    9505
# Autonòmica           4108
# Estatal              2529
# Provincial           1853
# Municipal            1437
# Altres                269
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_TRACAT_ALTIMETRIC':
# D_TRACAT_ALTIMETRIC
# Sense Especificar    9569
# Pla                  5732
# Rampa o pendent      4135
# Canvi rasant          252
# Gual                   13
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'D_VENT':
# D_VENT
# Calma, vent molt suau    19318
# Vent moderat               303
# Vent fort                   78
# Sense especificar            2
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'grupHor':
# grupHor
# Tarda    9204
# Matí     7990
# Nit      2507
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'tipAcc':
# tipAcc
# Col.lisió de vehicles en marxa                             9294
# Atropellament                                              4104
# Sortida de la calcada sense especificar                    2449
# Bolcada a la calcada                                       1877
# Col.lisió d'un vehicle contra un obstacle de la calcada    1058
# Altres                                                      919
# Name: count, dtype: int64
# ----------------------------------------
#
# Unique values in column 'tipDia':
# tipDia
# dill-dij    10909
# div          3124
# dis          2991
# dg           2677
# Name: count, dtype: int64
# ----------------------------------------

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19701 entries, 0 to 24476
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Any                        19701 non-null  int64
#  1   zona                       19701 non-null  object
#  2   nomCom                     19701 non-null  object
#  3   nomDem                     19701 non-null  object
#  4   F_MORTS                    19701 non-null  int64
#  5   F_FERITS_GREUS             19701 non-null  int64
#  6   F_FERITS_LLEUS             19701 non-null  int64
#  7   F_VICTIMES                 19701 non-null  int64
#  8   F_UNITATS_IMPLICADES       19701 non-null  int64
#  9   F_VIANANTS_IMPLICADES      19701 non-null  int64
#  10  F_BICICLETES_IMPLICADES    19701 non-null  int64
#  11  F_CICLOMOTORS_IMPLICADES   19701 non-null  int64
#  12  F_MOTOCICLETES_IMPLICADES  19701 non-null  int64
#  13  F_VEH_LLEUGERS_IMPLICADES  19701 non-null  int64
#  14  F_VEH_PESANTS_IMPLICADES   19701 non-null  int64
#  15  C_VELOCITAT_VIA            19701 non-null  float64
#  16  D_BOIRA                    19701 non-null  object
#  17  D_CARACT_ENTORN            19701 non-null  object
#  18  D_CARRIL_ESPECIAL          19701 non-null  object
#  19  D_CIRCULACIO_MESURES_ESP   19701 non-null  object
#  20  D_CLIMATOLOGIA             19701 non-null  object
#  21  D_FUNC_ESP_VIA             19701 non-null  object
#  22  D_INTER_SECCIO             19701 non-null  object
#  23  D_LIMIT_VELOCITAT          19701 non-null  object
#  24  D_LLUMINOSITAT             19701 non-null  object
#  25  D_REGULACIO_PRIORITAT      19701 non-null  object
#  26  D_SENTITS_VIA              19701 non-null  object
#  27  D_SUBTIPUS_ACCIDENT        19701 non-null  object
#  28  D_SUBTIPUS_TRAM            19701 non-null  object
#  29  D_SUBZONA                  19701 non-null  object
#  30  D_SUPERFICIE               19701 non-null  object
#  31  D_TIPUS_VIA                19701 non-null  object
#  32  D_TITULARITAT_VIA          19701 non-null  object
#  33  D_TRACAT_ALTIMETRIC        19701 non-null  object
#  34  D_VENT                     19701 non-null  object
#  35  hor                        19701 non-null  float64
#  36  grupHor                    19701 non-null  object
#  37  tipAcc                     19701 non-null  object
#  38  tipDia                     19701 non-null  object
#  39  Mes                        19701 non-null  int32
# dtypes: float64(2), int32(1), int64(12), object(25)
# memory usage: 6.1+ MB

# %%
cat_cols = df.select_dtypes(include=['object']).columns
print("Categorical Columns:")
print(cat_cols)
# Out:
# Categorical Columns:
# Index(['zona', 'nomCom', 'nomDem', 'D_BOIRA', 'D_CARACT_ENTORN',
#        'D_CARRIL_ESPECIAL', 'D_CIRCULACIO_MESURES_ESP', 'D_CLIMATOLOGIA',
#        'D_FUNC_ESP_VIA', 'D_INTER_SECCIO', 'D_LIMIT_VELOCITAT',
#        'D_LLUMINOSITAT', 'D_REGULACIO_PRIORITAT', 'D_SENTITS_VIA',
#        'D_SUBTIPUS_ACCIDENT', 'D_SUBTIPUS_TRAM', 'D_SUBZONA', 'D_SUPERFICIE',
#        'D_TIPUS_VIA', 'D_TITULARITAT_VIA', 'D_TRACAT_ALTIMETRIC', 'D_VENT',
#        'grupHor', 'tipAcc', 'tipDia'],
#       dtype='object')

# %%
le_dict = {}
for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    le_dict[col] = le  # Save encoders for inverse transform later

# %% [markdown]
# ## 2.6 Feature engineering

# %% [markdown]
# Create "mortality" column: 1 if >=1 death, 0 else.

# %%
# Create "mortality" column: 1 if >=1 death, 0 else.
df['Mortalitat'] = (df['F_MORTS'] > 0).astype(int)

# %%
df.head()
# Out:
#     Any  zona  nomCom  nomDem  F_MORTS  F_FERITS_GREUS  F_FERITS_LLEUS  \
# 0  2010     1      42       0        0               1               0
# 1  2010     0      34       2        0               1               3
# 2  2010     0      20       1        1               0               2
# 3  2010     1      13       0        0               2               7
# 4  2010     1      13       0        0               1               0
#
#    F_VICTIMES  F_UNITATS_IMPLICADES  F_VIANANTS_IMPLICADES  ...  D_TIPUS_VIA  \
# 0           1                     2                      0  ...            5
# 1           4                     1                      0  ...            4
# 2           3                     4                      0  ...            4
# 3           9                     2                      0  ...            5
# 4           1                     1                      0  ...            5
#
#    D_TITULARITAT_VIA  D_TRACAT_ALTIMETRIC  D_VENT    hor  grupHor  tipAcc  \
# 0                  5                    4       0  23.33        1       4
# 1                  2                    2       0   1.00        1       5
# 2                  2                    3       0  15.27        2       4
# 3                  5                    4       0  22.30        1       4
# 4                  5                    4       0  17.45        2       2
#
#    tipDia  Mes  Mortalitat
# 0       1    1           0
# 1       0   10           0
# 2       1    5           1
# 3       2    8           0
# 4       3    5           0
#
# [5 rows x 41 columns]

# %% [markdown]
# ## 2.7 Save label encoders and cleaned dataset

# %%
# TODO
